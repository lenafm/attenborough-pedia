# %%
# Out:
# ...
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...

# %%
import numpy as np
import pandas as pd
from os import path
from collections import Counter
from PIL import Image
import json
import string
from itertools import combinations

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = "output/birds.json"
with open(filename, "rt") as f:
    data = f.read()
    birds = json.loads(data)
    
print(birds)
# Out:
# {'sparrow': 12, 'falcon': 9, 'shearwater': 15, 'parrot': 16, 'kea': 3, 'owl': 22, 'winter': 17, 'buzzard': 8, 'kestrel': 10, 'vulture': 38, 'turkey': 4, 'eagle': 25, 'flamingo': 8, 'hawk': 36, 'shrike': 3, 'sparrowhawk': 1, 'goshawk': 5, 'pigeon': 16, 'tern': 10, 'fairy': 5, 'swift': 9, 'martin': 11, 'woodpecker': 31, 'hornbill': 12, 'booby': 21, 'duck': 25, 'swallow': 1, 'cisticola': 1, 'warbler': 17, 'nuthatch': 3, 'weaver': 17, 'avocet': 7, 'plover': 16, 'kiwi': 5, 'tit': 9, 'cacique': 5, 'toucan': 1, 'currawong': 3, 'thornbill': 1, 'wren': 9, 'maleo': 4, 'canvasback': 9, 'redhead': 5, 'cuckoo': 35, 'fantail': 13, 'cowbird': 4, 'gnatcatcher': 2, 'wrybill': 1, 'dipper': 7, 'kingfisher': 14, 'crow': 11, 'darter': 2, 'egret': 8, 'heron': 6, 'spoonbill': 5, 'cormorant': 3, 'skimmer': 4, 'gull': 8, 'mallard': 8, 'merganser': 4, 'stork': 11, 'shoebill': 3, 'godwit': 1, 'dowitcher': 1, 'sanderling': 1, 'pelican': 21, 'auk': 3, 'guillemot': 2, 'puffin': 1, 'penguin': 16, 'petrel': 8, 'alb
# ...

# %%
mask = np.array(Image.open("masks/bird.png"))

# Create and generate a word cloud image:
text = ' '.join(birds)
wordcloud = WordCloud(background_color="white",mask = mask).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
counts = sorted(birds.items(), key=lambda item: item[1], reverse = True)
    
# make labels & vals for the histogram
labels = np.array(birds.keys)
values = np.array(birds.values)

print("Shape of the array = ", np.shape(IndSort));
print(counts)
# Out:
# Shape of the array =  ()
# ...

# %%
# make labels & vals for the histogram
labels = np.array(birds.keys)
values = np.array(birds.values)

indexes = np.arange(np.size(labels))

bar_width = 0.35

n_max = 10
plt.bar(indexes[:n_max], values[:n_max])

# add labels
plt.xticks(indexes[:n_max] + bar_width, labels[:n_max], ha='right', rotation = 90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [48], in <cell line: 10>()
#       7 bar_width = 0.35
#       9 n_max = 10
# ---> 10 plt.bar(indexes[:n_max], values[:n_max])
#      12 # add labels
#      13 plt.xticks(indexes[:n_max] + bar_width, labels[:n_max], ha='right', rotation = 90)
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
